# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonochy/UoA_school_mission-12/blob/dev/Simple_imageClassifier_original_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# コードをクローン

# %%
# !git clone https://github.com/Sonochy/Simple_imageClassifier.git
# Out:
# Cloning into 'Simple_imageClassifier'...
# remote: Enumerating objects: 542, done.
# remote: Counting objects: 100% (542/542), done.
# remote: Compressing objects: 100% (539/539), done.
# remote: Total 542 (delta 11), reused 520 (delta 2), pack-reused 0
# Receiving objects: 100% (542/542), 8.60 MiB | 26.07 MiB/s, done.
# Resolving deltas: 100% (11/11), done.

# %%
import os

# %%
os.chdir("Simple_imageClassifier")

# %%
# !rm -r ./list
# Out:
# rm: cannot remove './list': No such file or directory

# %% [markdown]
# 学習

# %%
# !python train.py
# Out:
# Using TensorFlow backend.
# Lists do not exist. Create list from ./data.
# train samples:  407
# test samples:  101
# building the model ...
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3005: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# Train on 407 samples, validate on 101 samples
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2020-03-04 09:28:25.936754: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-04 09:28:25.937145: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x315d2c0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-04 09:28:25.937185: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-04 09:28:25.964746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-04 09:28:26.055049: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-03-04 09:28:26.055126: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c1f79c9d384b): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1068: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1112: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1122: The name tf.summary.merge_all is deprecated. Please use tf.compat.v1.summary.merge_all instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1125: The name tf.summary.FileWriter is deprecated. Please use tf.compat.v1.summary.FileWriter instead.
#
# Epoch 1/20
# 407/407 [==============================] - 36s 89ms/step - loss: 2.5970 - acc: 0.3096 - val_loss: 1.2788 - val_acc: 0.3663
#
# Epoch 00001: val_acc improved from -inf to 0.36634, saving model to ./20200304092822/acc_best_20200304092822.model
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/callbacks.py:1265: The name tf.Summary is deprecated. Please use tf.compat.v1.Summary instead.
#
# Epoch 2/20
# 407/407 [==============================] - 35s 86ms/step - loss: 0.9852 - acc: 0.5209 - val_loss: 0.9117 - val_acc: 0.5248
#
# Epoch 00002: val_acc improved from 0.36634 to 0.52475, saving model to ./20200304092822/acc_best_20200304092822.model
# Epoch 3/20
#  80/407 [====>.........................] - ETA: 27s - loss: 0.7887 - acc: 0.6250Traceback (most recent call last):
#   File "train.py", line 149, in <module>
#     callbacks = [es_cb, mc_cb, tb_cb])
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 1178, in fit
#     validation_freq=validation_freq)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training_arrays.py", line 204, in fit_loop
#     outs = fit_function(ins_batch)
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 2979, in __call__
#     return self._call(inputs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py", line 2937, in _call
#     fetched = self._callable_fn(*array_vals)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow_core/python/client/session.py", line 1472, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %% [markdown]
# test画像一覧表示

# %%
# %cat ./list/test.lst
# Out:
# ./data/Shadow/615.png
# ./data/Ccfh/5958.png
# ./data/Shadow/3112.png
# ./data/Ccp/3872.png
# ./data/Mp/181.png
# ./data/Ccp/14592.png
# ./data/Ccfs/243.png
# ./data/Ccp/399.png
# ./data/Ccfs/3.png
# ./data/Mp/176.png
# ./data/Ccfs/163.png
# ./data/Ccp/1811.png
# ./data/Ccfs/136.png
# ./data/Shadow/638.png
# ./data/Shadow/1116.png
# ./data/Shadow/431.png
# ./data/Ccfs/93.png
# ./data/Ccfs/165.png
# ./data/Shadow/582.png
# ./data/Ccp/750.png
# ./data/Mp/870.png
# ./data/Ccfs/277.png
# ./data/Ccp/3690.png
# ./data/Ccfh/382.png
# ./data/Ccp/14512.png
# ./data/Mp/96.png
# ./data/Ccp/3550.png
# ./data/Mp/81.png
# ./data/Ccp/15102.png
# ./data/Shadow/446.png
# ./data/Ccfs/206.png
# ./data/Ccp/14981.png
# ./data/Mp/85.png
# ./data/Shadow/688.png
# ./data/Mp/5719.png
# ./data/Shadow/727.png
# ./data/Shadow/654.png
# ./data/Ccfh/6118.png
# ./data/Ccfh/281.png
# ./data/Shadow/90.png
# ./data/Ccfs/241.png
# ./data/Shadow/531.png
# ./data/Ccfs/121.png
# ./data/Mp/902.png
# ./data/Ccfh/5653.png
# ./data/Ccp/3963.png
# ./data/Ccp/14551.png
# ./data/Mp/175.png
# ./data/Ccfh/2679.png
# ./data/Mp/5052.png
# ./data/Ccfs/202.png
# ./data/Ccfs/118.png
# ./data/Mp/4628.png
# ./data/Mp/1309.png
# ./data/Mp/84.png
# ./data/Ccfh/3554.png
# ./data/Shadow/1008.png
# ./data/Ccp/3717.png
# ./data/Ccp/15219.png
# ./data/Mp/54.png
# ./data/Ccp/15140.png
# ./data/Mp/7.png
# ./data/Ccfs/207.png
# ./data/Mp/165.png
# ./data/Mp/3.png
# ./data/Ccfs/56.png
# ./data/Ccfs/240.png
# ./data/Mf/785.png
# ./data/Ccp/3763.png
# ./data/Mp/82.png
# ./data/Ccfs/208.png
# ./data/Mp/1862.png
# ./data/Ccp/855.png
# ./data/Ccp/3569.png
# ./data/Ccfh/5921.png
# ./data/Ccfh/436.png
# ./data/Ccfs/66.png
# ./data/Ccfh/695.png
# ./data/Ccfh/577.png
# ./data/Shadow/636.png
# ./data/Mp/52.png
# ./data/Shadow/261.png
# ./data/Shadow/3142.png
# ./data/Ccp/3949.png
# ./data/Ccp/3633.png
# ./data/Ccfh/3529.png
# ./data/Shadow/1031.png
# ./data/Shadow/3014.png
# ./data/Shadow/3098.png
# ./data/Mp/178.png
# ./data/Ccp/381.png
# ./data/Ccfh/435.png
# ./data/Ccfs/84.png
# ./data/Ccfh/2212.png
# ./data/Ccp/3889.png
# ./data/Mp/161.png
# ./data/Ccfh/2827.png
# ./data/Mp/1863.png
# ./data/Ccfh/240.png
# ./data/Shadow/74.png
# ./data/Shadow/323.png

# %% [markdown]
# test実行

# %%
# %ls -l
# !python test.py --model ./2020*/*.model
# Out:
# total 92
# drwxr-xr-x 2 root root  4096 Mar  4 09:29 20200304092822/
# drwxr-xr-x 8 root root  4096 Mar  4 09:27 data/
# -rw-r--r-- 1 root root  1064 Mar  4 09:27 LICENSE
# drwxr-xr-x 2 root root  4096 Mar  4 09:28 list/
# -rw-r--r-- 1 root root 47642 Mar  4 09:28 model.png
# drwxr-xr-x 2 root root  4096 Mar  4 09:28 __pycache__/
# -rw-r--r-- 1 root root   104 Mar  4 09:27 README.md
# -rw-r--r-- 1 root root  2573 Mar  4 09:27 test.py
# -rw-r--r-- 1 root root  6951 Mar  4 09:27 train.py
# -rw-r--r-- 1 root root  4409 Mar  4 09:27 utils.py
# Using TensorFlow backend.
# Lists exist in ./list. Use the test list.
# test samples:  101
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:148: The name tf.placeholder_with_default is deprecated. Please use tf.compat.v1.placeholder_with_default instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3733: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:203: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# 2020-03-04 09:30:56.275510: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2300000000 Hz
# 2020-03-04 09:30:56.275796: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0xa3c3100 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-04 09:30:56.275831: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-04 09:30:56.278129: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-04 09:30:56.280082: E tensorflow/stream_executor/cuda/cuda_driver.cc:318] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2020-03-04 09:30:56.280129: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (c1f79c9d384b): /proc/driver/nvidia/version does not exist
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:207: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:216: The name tf.is_variable_initialized is deprecated. Please use tf.compat.v1.is_variable_initialized instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:223: The name tf.variables_initializer is deprecated. Please use tf.compat.v1.variables_initializer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3576: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1033: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:1020: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# ./data/Shadow/615.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfh/5958.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 0.99 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/3112.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/3872.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.06 Shadow: 0.00 Mp: 0.23 Ccp: 0.23 Mf: 0.01 Ccfs: 0.47
# ------------------------------------
#
# ./data/Mp/181.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.13 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.33
# ------------------------------------
#
# ./data/Ccp/14592.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.06 Shadow: 0.00 Mp: 0.22 Ccp: 0.24 Mf: 0.00 Ccfs: 0.48
# ------------------------------------
#
# ./data/Ccfs/243.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.10 Shadow: 0.02 Mp: 0.25 Ccp: 0.22 Mf: 0.03 Ccfs: 0.38
# ------------------------------------
#
# ./data/Ccp/399.png
# Incorrect...
# answer: Ccp
# predict: Ccfh
# Ccfh: 0.68 Shadow: 0.00 Mp: 0.04 Ccp: 0.24 Mf: 0.00 Ccfs: 0.03
# ------------------------------------
#
# ./data/Ccfs/3.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Mp/176.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.12 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.34
# ------------------------------------
#
# ./data/Ccfs/163.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Ccp/1811.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.05 Shadow: 0.00 Mp: 0.20 Ccp: 0.27 Mf: 0.00 Ccfs: 0.48
# ------------------------------------
#
# ./data/Ccfs/136.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Shadow/638.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/1116.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/431.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/93.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Ccfs/165.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Shadow/582.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/750.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.06 Shadow: 0.00 Mp: 0.24 Ccp: 0.22 Mf: 0.01 Ccfs: 0.47
# ------------------------------------
#
# ./data/Mp/870.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.14 Shadow: 0.04 Mp: 0.26 Ccp: 0.20 Mf: 0.05 Ccfs: 0.31
# ------------------------------------
#
# ./data/Ccfs/277.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.12 Shadow: 0.02 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.35
# ------------------------------------
#
# ./data/Ccp/3690.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.05 Shadow: 0.00 Mp: 0.22 Ccp: 0.22 Mf: 0.00 Ccfs: 0.50
# ------------------------------------
#
# ./data/Ccfh/382.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/14512.png
# Incorrect...
# answer: Ccp
# predict: Ccfh
# Ccfh: 0.33 Shadow: 0.00 Mp: 0.23 Ccp: 0.16 Mf: 0.01 Ccfs: 0.27
# ------------------------------------
#
# ./data/Mp/96.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.29
# ------------------------------------
#
# ./data/Ccp/3550.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.14 Shadow: 0.00 Mp: 0.25 Ccp: 0.23 Mf: 0.00 Ccfs: 0.37
# ------------------------------------
#
# ./data/Mp/81.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.04 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.29
# ------------------------------------
#
# ./data/Ccp/15102.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.07 Shadow: 0.00 Mp: 0.24 Ccp: 0.23 Mf: 0.01 Ccfs: 0.45
# ------------------------------------
#
# ./data/Shadow/446.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/206.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Ccp/14981.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.07 Shadow: 0.00 Mp: 0.24 Ccp: 0.23 Mf: 0.01 Ccfs: 0.45
# ------------------------------------
#
# ./data/Mp/85.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.28
# ------------------------------------
#
# ./data/Shadow/688.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Mp/5719.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.14 Shadow: 0.04 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.30
# ------------------------------------
#
# ./data/Shadow/727.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/654.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfh/6118.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 0.50 Shadow: 0.01 Mp: 0.19 Ccp: 0.13 Mf: 0.01 Ccfs: 0.16
# ------------------------------------
#
# ./data/Ccfh/281.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 0.99 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/90.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/241.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Shadow/531.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/121.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Mp/902.png
# Correct!!!
# answer: Mp
# predict: Mp
# Ccfh: 0.20 Shadow: 0.07 Mp: 0.26 Ccp: 0.16 Mf: 0.07 Ccfs: 0.25
# ------------------------------------
#
# ./data/Ccfh/5653.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/3963.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.07 Shadow: 0.01 Mp: 0.24 Ccp: 0.22 Mf: 0.01 Ccfs: 0.44
# ------------------------------------
#
# ./data/Ccp/14551.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.09 Shadow: 0.01 Mp: 0.26 Ccp: 0.21 Mf: 0.01 Ccfs: 0.42
# ------------------------------------
#
# ./data/Mp/175.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.12 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.34
# ------------------------------------
#
# ./data/Ccfh/2679.png
# Incorrect...
# answer: Ccfh
# predict: Ccfs
# Ccfh: 0.19 Shadow: 0.03 Mp: 0.27 Ccp: 0.20 Mf: 0.03 Ccfs: 0.28
# ------------------------------------
#
# ./data/Mp/5052.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.18 Shadow: 0.04 Mp: 0.27 Ccp: 0.18 Mf: 0.05 Ccfs: 0.28
# ------------------------------------
#
# ./data/Ccfs/202.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.10 Shadow: 0.02 Mp: 0.25 Ccp: 0.22 Mf: 0.03 Ccfs: 0.38
# ------------------------------------
#
# ./data/Ccfs/118.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.10 Shadow: 0.02 Mp: 0.25 Ccp: 0.22 Mf: 0.02 Ccfs: 0.39
# ------------------------------------
#
# ./data/Mp/4628.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.29
# ------------------------------------
#
# ./data/Mp/1309.png
# Incorrect...
# answer: Mp
# predict: Ccfh
# Ccfh: 0.50 Shadow: 0.05 Mp: 0.21 Ccp: 0.08 Mf: 0.02 Ccfs: 0.14
# ------------------------------------
#
# ./data/Mp/84.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.29
# ------------------------------------
#
# ./data/Ccfh/3554.png
# Incorrect...
# answer: Ccfh
# predict: Ccfs
# Ccfh: 0.18 Shadow: 0.02 Mp: 0.27 Ccp: 0.19 Mf: 0.02 Ccfs: 0.31
# ------------------------------------
#
# ./data/Shadow/1008.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/3717.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.06 Shadow: 0.00 Mp: 0.23 Ccp: 0.23 Mf: 0.00 Ccfs: 0.47
# ------------------------------------
#
# ./data/Ccp/15219.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.00 Mp: 0.25 Ccp: 0.24 Mf: 0.00 Ccfs: 0.40
# ------------------------------------
#
# ./data/Mp/54.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.07 Ccfs: 0.28
# ------------------------------------
#
# ./data/Ccp/15140.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.17 Shadow: 0.00 Mp: 0.25 Ccp: 0.21 Mf: 0.00 Ccfs: 0.37
# ------------------------------------
#
# ./data/Mp/7.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.16 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.28
# ------------------------------------
#
# ./data/Ccfs/207.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.21 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Mp/165.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.17 Shadow: 0.05 Mp: 0.26 Ccp: 0.19 Mf: 0.06 Ccfs: 0.27
# ------------------------------------
#
# ./data/Mp/3.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.17 Shadow: 0.04 Mp: 0.27 Ccp: 0.19 Mf: 0.05 Ccfs: 0.29
# ------------------------------------
#
# ./data/Ccfs/56.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.36
# ------------------------------------
#
# ./data/Ccfs/240.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Mf/785.png
# Incorrect...
# answer: Mf
# predict: Ccfh
# Ccfh: 0.41 Shadow: 0.01 Mp: 0.23 Ccp: 0.11 Mf: 0.01 Ccfs: 0.23
# ------------------------------------
#
# ./data/Ccp/3763.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.08 Shadow: 0.00 Mp: 0.25 Ccp: 0.25 Mf: 0.01 Ccfs: 0.41
# ------------------------------------
#
# ./data/Mp/82.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.14 Shadow: 0.04 Mp: 0.26 Ccp: 0.20 Mf: 0.05 Ccfs: 0.30
# ------------------------------------
#
# ./data/Ccfs/208.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.12 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.35
# ------------------------------------
#
# ./data/Mp/1862.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.13 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.05 Ccfs: 0.32
# ------------------------------------
#
# ./data/Ccp/855.png
# Incorrect...
# answer: Ccp
# predict: Ccfh
# Ccfh: 0.59 Shadow: 0.00 Mp: 0.05 Ccp: 0.31 Mf: 0.00 Ccfs: 0.05
# ------------------------------------
#
# ./data/Ccp/3569.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.00 Mp: 0.26 Ccp: 0.23 Mf: 0.01 Ccfs: 0.39
# ------------------------------------
#
# ./data/Ccfh/5921.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 0.99 Shadow: 0.00 Mp: 0.01 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfh/436.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/66.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.12 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.34
# ------------------------------------
#
# ./data/Ccfh/695.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfh/577.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/636.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Mp/52.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.28
# ------------------------------------
#
# ./data/Shadow/261.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/3142.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/3949.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.07 Shadow: 0.01 Mp: 0.24 Ccp: 0.23 Mf: 0.01 Ccfs: 0.44
# ------------------------------------
#
# ./data/Ccp/3633.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.05 Shadow: 0.00 Mp: 0.23 Ccp: 0.22 Mf: 0.01 Ccfs: 0.48
# ------------------------------------
#
# ./data/Ccfh/3529.png
# Incorrect...
# answer: Ccfh
# predict: Ccfs
# Ccfh: 0.24 Shadow: 0.01 Mp: 0.26 Ccp: 0.21 Mf: 0.01 Ccfs: 0.28
# ------------------------------------
#
# ./data/Shadow/1031.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/3014.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/3098.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Mp/178.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.13 Shadow: 0.03 Mp: 0.26 Ccp: 0.21 Mf: 0.04 Ccfs: 0.33
# ------------------------------------
#
# ./data/Ccp/381.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.06 Shadow: 0.00 Mp: 0.24 Ccp: 0.23 Mf: 0.01 Ccfs: 0.47
# ------------------------------------
#
# ./data/Ccfh/435.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccfs/84.png
# Correct!!!
# answer: Ccfs
# predict: Ccfs
# Ccfh: 0.11 Shadow: 0.02 Mp: 0.26 Ccp: 0.22 Mf: 0.03 Ccfs: 0.37
# ------------------------------------
#
# ./data/Ccfh/2212.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 0.94 Shadow: 0.06 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Ccp/3889.png
# Incorrect...
# answer: Ccp
# predict: Ccfs
# Ccfh: 0.07 Shadow: 0.00 Mp: 0.24 Ccp: 0.22 Mf: 0.01 Ccfs: 0.46
# ------------------------------------
#
# ./data/Mp/161.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.15 Shadow: 0.05 Mp: 0.26 Ccp: 0.20 Mf: 0.06 Ccfs: 0.29
# ------------------------------------
#
# ./data/Ccfh/2827.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Mp/1863.png
# Incorrect...
# answer: Mp
# predict: Ccfs
# Ccfh: 0.14 Shadow: 0.04 Mp: 0.26 Ccp: 0.20 Mf: 0.05 Ccfs: 0.31
# ------------------------------------
#
# ./data/Ccfh/240.png
# Correct!!!
# answer: Ccfh
# predict: Ccfh
# Ccfh: 1.00 Shadow: 0.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/74.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# ./data/Shadow/323.png
# Correct!!!
# answer: Shadow
# predict: Shadow
# Ccfh: 0.00 Shadow: 1.00 Mp: 0.00 Ccp: 0.00 Mf: 0.00 Ccfs: 0.00
# ------------------------------------
#
# | Num_of_Correct_data: 53
# | Num_of_Incorrect_data: 48
#
# | Incorrect_data_list: ['Ccfh/2679.png', 'Ccfh/3529.png', 'Ccfh/3554.png', 'Ccp/14512.png', 'Ccp/14551.png', 'Ccp/14592.png', 'Ccp/14981.png', 'Ccp/15102.png', 'Ccp/15140.png', 'Ccp/15219.png', 'Ccp/1811.png', 'Ccp/3550.png', 'Ccp/3569.png', 'Ccp/3633.png', 'Ccp/3690.png', 'Ccp/3717.png', 'Ccp/3763.png', 'Ccp/381.png', 'Ccp/3872.png', 'Ccp/3889.png', 'Ccp/3949.png', 'Ccp/3963.png', 'Ccp/399.png', 'Ccp/750.png', 'Ccp/855.png', 'Mf/785.png', 'Mp/1309.png', 'Mp/161.png', 'Mp/165.png', 'Mp/175.png', 'Mp/176.png', 'Mp/178.png', 'Mp/181.png', 'Mp/1862.png', 'Mp/1863.png', 'Mp/3.png', 'Mp/4628.png', 'Mp/5052.png', 'Mp/52.png', 'Mp/54.png', 'Mp/5719.png', 'Mp/7.png', 'Mp/81.png', 'Mp/82.png', 'Mp/84.png', 'Mp/85.png', 'Mp/870.png', 'Mp/96.png']
#
# | Accuracy:52.475247524752476 %
