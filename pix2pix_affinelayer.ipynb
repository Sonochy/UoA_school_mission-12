# %% [markdown]
# <a href="https://colab.research.google.com/github/Sonochy/UoA_school_mission-12/blob/dev/pix2pix_affinelayer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## [惑星探査育英会　第十二回実習会](https://www.cps-jp.org/~tansaku/wiki/top/?school_mission-12)
# pix2pixを用いたsemantic segmentation

# %% [markdown]
# ## 参考URL
#
#
#
# *   [Colaboratory へようこそ](https://colab.research.google.com/notebooks/welcome.ipynb?hl=ja#scrollTo=-Rh3-Vt9Nev9)
# *   [Google Colaboratoryでpix2pixを動かしてみる。](https://qiita.com/simonritchie/items/09b2810f0bcf12305719)
# *   [Google Colaboratory での Terminal 操作](https://qiita.com/shirobu2400/items/2fad1d24053b7cb35547)
# *   [Google Colaboratoryをもっと便利に使いたい](https://karaage.hatenadiary.jp/entry/2018/12/17/073000)

# %% [markdown]
# ## スペック確認

# %%
#@title OS確認
# !cat /etc/issue
# Out:
# Ubuntu 18.04.3 LTS \n \l

# %%
#@title メモリ確認
# !free -h
# Out:
#               total        used        free      shared  buff/cache   available
# Mem:            12G        573M         10G        904K        2.1G         11G
# Swap:            0B          0B          0B

# %%
#@title CPUのスペック確認
# !cat /proc/cpuinfo
# Out:
# processor	: 0
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 0
# initial apicid	: 0
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:
#
# processor	: 1
# vendor_id	: GenuineIntel
# cpu family	: 6
# model		: 79
# model name	: Intel(R) Xeon(R) CPU @ 2.20GHz
# stepping	: 0
# microcode	: 0x1
# cpu MHz		: 2200.000
# cache size	: 56320 KB
# physical id	: 0
# siblings	: 2
# core id		: 0
# cpu cores	: 1
# apicid		: 1
# initial apicid	: 1
# fpu		: yes
# fpu_exception	: yes
# cpuid level	: 13
# wp		: yes
# flags		: fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht syscall nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single ssbd ibrs ibpb stibp fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms invpcid rtm rdseed adx smap xsaveopt arat md_clear arch_capabilities
# bugs		: cpu_meltdown spectre_v1 spectre_v2 spec_store_bypass l1tf mds swapgs
# bogomips	: 4400.00
# clflush size	: 64
# cache_alignment	: 64
# address sizes	: 46 bits physical, 48 bits virtual
# power management:

# %%
#@title GPUのスペック確認
# !cat /proc/driver/nvidia/gpus/0000:00:04.0/information
# Out:
# Model: 		 Tesla K80
# IRQ:   		 35
# GPU UUID: 	 GPU-7586f344-93c3-af9d-b2e9-3fa7c0f807ab
# Video BIOS: 	 80.21.25.00.01
# Bus Type: 	 PCI
# DMA Size: 	 40 bits
# DMA Mask: 	 0xffffffffff
# Bus Location: 	 0000:00:04.0
# Device Minor: 	 0
# Blacklisted:	 No

# %%
#@title Google Colabの起動してからの時間確認
# !cat /proc/uptime | awk '{print $1 /60 /60 /24 "days (" $1 "sec)"}'
# Out:
# 0.00803171days (693.94sec)

# %% [markdown]
# ## ライブラリ Install

# %% [markdown]
# ## ドライブにマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ## pix2pixのサンプル実行

# %%
# !pwd
# !ls
# Out:
# /content
# drive  sample_data

# %%
# !git clone https://github.com/affinelayer/pix2pix-tensorflow.git
# Out:
# Cloning into 'pix2pix-tensorflow'...
# remote: Enumerating objects: 261, done.
# remote: Total 261 (delta 0), reused 0 (delta 0), pack-reused 261
# Receiving objects: 100% (261/261), 13.33 MiB | 6.44 MiB/s, done.
# Resolving deltas: 100% (103/103), done.

# %%
# %cd pix2pix-tensorflow
# !ls
# Out:
# /content/pix2pix-tensorflow
# docker	docs  LICENSE.txt  pix2pix.py  README.md  server  tools

# %%
# !python tools/download-dataset.py facades
# Out:
# downloading https://people.eecs.berkeley.edu/~tinghuiz/projects/pix2pix/datasets/facades.tar.gz
# extracting
# done

# %%
#@title facadesサンプルの学習
# !python pix2pix.py \
  --mode train \
  --output_dir facades_train \
  --max_epochs 10 \
  --input_dir facades/train \
  --which_direction BtoA
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = None
# display_freq = 0
# flip = True
# gan_weight = 1.0
# input_dir = facades/train
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = 10
# max_steps = None
# mode = train
# ndf = 64
# ngf = 64
# output_dir = facades_train
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 286
# seed = 1142950123
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From pix2pix.py:259: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# WARNING:tensorflow:From pix2pix.py:264: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From pix2pix.py:299: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From pix2pix.py:301: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From pix2pix.py:314: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# examples count = 400
# WARNING:tensorflow:From pix2pix.py:428: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From pix2pix.py:105: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From pix2pix.py:132: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From pix2pix.py:116: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# WARNING:tensorflow:From pix2pix.py:379: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From pix2pix.py:448: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From pix2pix.py:458: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From pix2pix.py:459: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From pix2pix.py:473: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From pix2pix.py:474: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From pix2pix.py:681: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From pix2pix.py:695: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From pix2pix.py:700: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From pix2pix.py:708: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From pix2pix.py:711: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-03-09 00:54:02.611168: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-09 00:54:02.663518: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:02.664298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-03-09 00:54:02.678821: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 00:54:02.902827: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-09 00:54:03.035126: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-09 00:54:03.061623: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-09 00:54:03.320548: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-09 00:54:03.345471: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-09 00:54:03.847552: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 00:54:03.847742: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.848557: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.849254: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-09 00:54:03.862169: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-09 00:54:03.866182: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x2c2aa00 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-09 00:54:03.866215: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-09 00:54:03.993384: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.994368: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x9a4f500 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-09 00:54:03.994397: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-03-09 00:54:03.995896: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.996679: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-03-09 00:54:03.996728: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 00:54:03.996752: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-09 00:54:03.996803: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-09 00:54:03.996856: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-09 00:54:03.996875: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-09 00:54:03.996894: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-09 00:54:03.996929: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 00:54:03.996998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.997858: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:03.998636: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-09 00:54:04.002984: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 00:54:04.004620: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-09 00:54:04.004656: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-09 00:54:04.004671: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-09 00:54:04.007227: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:04.007970: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 00:54:04.008691: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-09 00:54:04.008792: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# parameter_count = 57190084
# 2020-03-09 00:54:14.802510: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 00:54:18.837962: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# progress  epoch 1  step 49  image/sec 2.9  remaining 22m
# discrim_loss 0.59820104
# gen_loss_GAN 0.36205113
# gen_loss_L1 0.14008518
# recording summary
# progress  epoch 1  step 100  image/sec 3.2  remaining 20m
# discrim_loss 0.8326023
# gen_loss_GAN 0.6850787
# gen_loss_L1 0.22048597
# progress  epoch 1  step 150  image/sec 3.8  remaining 16m
# discrim_loss 0.76841944
# gen_loss_GAN 1.1399634
# gen_loss_L1 0.26907268
# recording summary
# progress  epoch 1  step 199  image/sec 3.9  remaining 16m
# discrim_loss 0.6807127
# gen_loss_GAN 1.5964397
# gen_loss_L1 0.30118516
# progress  epoch 1  step 249  image/sec 4.1  remaining 15m
# discrim_loss 0.6138741
# gen_loss_GAN 1.9082634
# gen_loss_L1 0.31750163
# recording summary
# progress  epoch 1  step 299  image/sec 4.1  remaining 15m
# discrim_loss 0.6343856
# gen_loss_GAN 1.9782916
# gen_loss_L1 0.3294999
# progress  epoch 1  step 349  image/sec 4.3  remaining 14m
# discrim_loss 0.599328
# gen_loss_GAN 2.101628
# gen_loss_L1 0.3376282
# recording summary
# progress  epoch 1  step 399  image/sec 4.2  remaining 14m
# discrim_loss 0.5540393
# gen_loss_GAN 2.2743032
# gen_loss_L1 0.33878207
# progress  epoch 2  step 50  image/sec 4.4  remaining 13m
# discrim_loss 0.58589727
# gen_loss_GAN 2.2412446
# gen_loss_L1 0.34363928
# recording summary
# progress  epoch 2  step 99  image/sec 4.3  remaining 13m
# discrim_loss 0.5557403
# gen_loss_GAN 2.298245
# gen_loss_L1 0.3465371
# progress  epoch 2  step 149  image/sec 4.4  remaining 12m
# discrim_loss 0.59933794
# gen_loss_GAN 2.3249497
# gen_loss_L1 0.3486487
# recording summary
# progress  epoch 2  step 200  image/sec 4.4  remaining 12m
# discrim_loss 0.5889668
# gen_loss_GAN 2.3436522
# gen_loss_L1 0.351238
# progress  epoch 2  step 249  image/sec 4.5  remaining 12m
# discrim_loss 0.5628637
# gen_loss_GAN 2.3866255
# gen_loss_L1 0.34935758
# recording summary
# progress  epoch 2  step 299  image/sec 4.4  remaining 12m
# discrim_loss 0.5931979
# gen_loss_GAN 2.3946772
# gen_loss_L1 0.34919003
# progress  epoch 2  step 349  image/sec 4.5  remaining 12m
# discrim_loss 0.52543354
# gen_loss_GAN 2.3990002
# gen_loss_L1 0.34455687
# recording summary
# progress  epoch 2  step 399  image/sec 4.5  remaining 11m
# discrim_loss 0.5821648
# gen_loss_GAN 2.3590689
# gen_loss_L1 0.3516123
# progress  epoch 3  step 49  image/sec 4.5  remaining 11m
# discrim_loss 0.5528653
# gen_loss_GAN 2.390654
# gen_loss_L1 0.35062188
# recording summary
# progress  epoch 3  step 100  image/sec 4.5  remaining 11m
# discrim_loss 0.53704494
# gen_loss_GAN 2.4189806
# gen_loss_L1 0.35492313
# progress  epoch 3  step 150  image/sec 4.5  remaining 11m
# discrim_loss 0.5583236
# gen_loss_GAN 2.385986
# gen_loss_L1 0.3517671
# recording summary
# progress  epoch 3  step 199  image/sec 4.5  remaining 11m
# discrim_loss 0.51713604
# gen_loss_GAN 2.6076312
# gen_loss_L1 0.35656807
# progress  epoch 3  step 249  image/sec 4.6  remaining 10m
# discrim_loss 0.50802237
# gen_loss_GAN 2.6225123
# gen_loss_L1 0.36159506
# recording summary
# progress  epoch 3  step 299  image/sec 4.5  remaining 10m
# discrim_loss 0.5723017
# gen_loss_GAN 2.522189
# gen_loss_L1 0.35599306
# progress  epoch 3  step 349  image/sec 4.6  remaining 10m
# discrim_loss 0.5858059
# gen_loss_GAN 2.4486947
# gen_loss_L1 0.3492173
# recording summary
# progress  epoch 3  step 399  image/sec 4.5  remaining 10m
# discrim_loss 0.5802225
# gen_loss_GAN 2.4321675
# gen_loss_L1 0.3487175
# progress  epoch 4  step 49  image/sec 4.6  remaining 10m
# discrim_loss 0.5974463
# gen_loss_GAN 2.4031737
# gen_loss_L1 0.34970286
# recording summary
# progress  epoch 4  step 99  image/sec 4.6  remaining 9m
# discrim_loss 0.6436542
# gen_loss_GAN 2.3762784
# gen_loss_L1 0.3487922
# progress  epoch 4  step 149  image/sec 4.6  remaining 9m
# discrim_loss 0.6188643
# gen_loss_GAN 2.3261104
# gen_loss_L1 0.35057586
# recording summary
# progress  epoch 4  step 199  image/sec 4.6  remaining 9m
# discrim_loss 0.57947445
# gen_loss_GAN 2.4033957
# gen_loss_L1 0.34974074
# progress  epoch 4  step 250  image/sec 4.6  remaining 9m
# discrim_loss 0.5915234
# gen_loss_GAN 2.3438947
# gen_loss_L1 0.35411534
# recording summary
# progress  epoch 4  step 299  image/sec 4.6  remaining 9m
# discrim_loss 0.57432055
# gen_loss_GAN 2.3500702
# gen_loss_L1 0.35244048
# progress  epoch 4  step 349  image/sec 4.6  remaining 8m
# discrim_loss 0.58812934
# gen_loss_GAN 2.3940072
# gen_loss_L1 0.35140502
# recording summary
# progress  epoch 4  step 399  image/sec 4.6  remaining 8m
# discrim_loss 0.6228711
# gen_loss_GAN 2.5003285
# gen_loss_L1 0.35188803
# progress  epoch 5  step 49  image/sec 4.6  remaining 8m
# discrim_loss 0.56096774
# gen_loss_GAN 2.492837
# gen_loss_L1 0.34960604
# recording summary
# progress  epoch 5  step 99  image/sec 4.6  remaining 8m
# discrim_loss 0.55913967
# gen_loss_GAN 2.5261295
# gen_loss_L1 0.35676417
# progress  epoch 5  step 149  image/sec 4.6  remaining 8m
# discrim_loss 0.558346
# gen_loss_GAN 2.5268965
# gen_loss_L1 0.3496245
# recording summary
# progress  epoch 5  step 199  image/sec 4.6  remaining 7m
# discrim_loss 0.5860171
# gen_loss_GAN 2.5097232
# gen_loss_L1 0.34851158
# progress  epoch 5  step 250  image/sec 4.6  remaining 7m
# discrim_loss 0.6236907
# gen_loss_GAN 2.45942
# gen_loss_L1 0.3477145
# recording summary
# progress  epoch 5  step 299  image/sec 4.6  remaining 7m
# discrim_loss 0.60229796
# gen_loss_GAN 2.4194992
# gen_loss_L1 0.34264407
# progress  epoch 5  step 350  image/sec 4.6  remaining 7m
# discrim_loss 0.61550534
# gen_loss_GAN 2.5302856
# gen_loss_L1 0.34968916
# recording summary
# progress  epoch 5  step 399  image/sec 4.6  remaining 7m
# discrim_loss 0.56169486
# gen_loss_GAN 2.533968
# gen_loss_L1 0.3499207
# progress  epoch 6  step 50  image/sec 4.6  remaining 7m
# discrim_loss 0.6258503
# gen_loss_GAN 2.466708
# gen_loss_L1 0.35999885
# recording summary
# progress  epoch 6  step 99  image/sec 4.6  remaining 6m
# discrim_loss 0.58364874
# gen_loss_GAN 2.4183393
# gen_loss_L1 0.35405734
# progress  epoch 6  step 149  image/sec 4.6  remaining 6m
# discrim_loss 0.58513165
# gen_loss_GAN 2.332454
# gen_loss_L1 0.3500363
# recording summary
# progress  epoch 6  step 200  image/sec 4.6  remaining 6m
# discrim_loss 0.6199655
# gen_loss_GAN 2.2710764
# gen_loss_L1 0.34555846
# progress  epoch 6  step 249  image/sec 4.6  remaining 6m
# discrim_loss 0.659633
# gen_loss_GAN 2.2865934
# gen_loss_L1 0.35207424
# recording summary
# progress  epoch 6  step 299  image/sec 4.6  remaining 6m
# discrim_loss 0.58832836
# gen_loss_GAN 2.3800538
# gen_loss_L1 0.35239545
# progress  epoch 6  step 350  image/sec 4.6  remaining 5m
# discrim_loss 0.5895969
# gen_loss_GAN 2.4620535
# gen_loss_L1 0.34644458
# recording summary
# progress  epoch 6  step 399  image/sec 4.6  remaining 5m
# discrim_loss 0.5853798
# gen_loss_GAN 2.447193
# gen_loss_L1 0.3497509
# progress  epoch 7  step 49  image/sec 4.6  remaining 5m
# discrim_loss 0.5529638
# gen_loss_GAN 2.453592
# gen_loss_L1 0.35236266
# recording summary
# progress  epoch 7  step 99  image/sec 4.6  remaining 5m
# discrim_loss 0.6019194
# gen_loss_GAN 2.4121625
# gen_loss_L1 0.34910282
# progress  epoch 7  step 149  image/sec 4.6  remaining 5m
# discrim_loss 0.5929977
# gen_loss_GAN 2.3613095
# gen_loss_L1 0.3506945
# recording summary
# progress  epoch 7  step 199  image/sec 4.6  remaining 5m
# discrim_loss 0.5955725
# gen_loss_GAN 2.4197884
# gen_loss_L1 0.34380814
# progress  epoch 7  step 249  image/sec 4.7  remaining 4m
# discrim_loss 0.6089852
# gen_loss_GAN 2.4558625
# gen_loss_L1 0.35170448
# recording summary
# progress  epoch 7  step 299  image/sec 4.6  remaining 4m
# discrim_loss 0.71730113
# gen_loss_GAN 2.3833725
# gen_loss_L1 0.35227314
# progress  epoch 7  step 349  image/sec 4.7  remaining 4m
# discrim_loss 0.6133468
# gen_loss_GAN 2.4193387
# gen_loss_L1 0.35226214
# recording summary
# progress  epoch 7  step 399  image/sec 4.6  remaining 4m
# discrim_loss 0.6660524
# gen_loss_GAN 2.3379974
# gen_loss_L1 0.3515752
# progress  epoch 8  step 50  image/sec 4.7  remaining 4m
# discrim_loss 0.63132256
# gen_loss_GAN 2.3361244
# gen_loss_L1 0.35102656
# recording summary
# progress  epoch 8  step 99  image/sec 4.6  remaining 3m
# discrim_loss 0.6083808
# gen_loss_GAN 2.3995178
# gen_loss_L1 0.34978366
# progress  epoch 8  step 150  image/sec 4.7  remaining 3m
# discrim_loss 0.6344969
# gen_loss_GAN 2.418528
# gen_loss_L1 0.34663162
# recording summary
# progress  epoch 8  step 199  image/sec 4.6  remaining 3m
# discrim_loss 0.6831747
# gen_loss_GAN 2.3516774
# gen_loss_L1 0.3484933
# progress  epoch 8  step 249  image/sec 4.7  remaining 3m
# discrim_loss 0.5965641
# gen_loss_GAN 2.4169056
# gen_loss_L1 0.34389645
# recording summary
# progress  epoch 8  step 299  image/sec 4.6  remaining 3m
# discrim_loss 0.5909093
# gen_loss_GAN 2.4048324
# gen_loss_L1 0.3449404
# progress  epoch 8  step 349  image/sec 4.7  remaining 3m
# discrim_loss 0.56267506
# gen_loss_GAN 2.3349204
# gen_loss_L1 0.3475042
# recording summary
# progress  epoch 8  step 399  image/sec 4.6  remaining 2m
# discrim_loss 0.64183706
# gen_loss_GAN 2.241064
# gen_loss_L1 0.34761697
# progress  epoch 9  step 50  image/sec 4.7  remaining 2m
# discrim_loss 0.6122587
# gen_loss_GAN 2.2682884
# gen_loss_L1 0.35269645
# recording summary
# progress  epoch 9  step 99  image/sec 4.7  remaining 2m
# discrim_loss 0.5912231
# gen_loss_GAN 2.4234552
# gen_loss_L1 0.35620597
# progress  epoch 9  step 149  image/sec 4.7  remaining 2m
# discrim_loss 0.58227456
# gen_loss_GAN 2.4772012
# gen_loss_L1 0.35206237
# recording summary
# progress  epoch 9  step 199  image/sec 4.7  remaining 2m
# discrim_loss 0.67288893
# gen_loss_GAN 2.351685
# gen_loss_L1 0.3438423
# progress  epoch 9  step 249  image/sec 4.7  remaining 1m
# discrim_loss 0.63644105
# gen_loss_GAN 2.3785477
# gen_loss_L1 0.34581727
# recording summary
# progress  epoch 9  step 299  image/sec 4.7  remaining 1m
# discrim_loss 0.57445174
# gen_loss_GAN 2.376157
# gen_loss_L1 0.34647477
# progress  epoch 9  step 350  image/sec 4.7  remaining 1m
# discrim_loss 0.62911874
# gen_loss_GAN 2.3674119
# gen_loss_L1 0.3405277
# recording summary
# progress  epoch 9  step 399  image/sec 4.7  remaining 1m
# discrim_loss 0.5866729
# gen_loss_GAN 2.3857932
# gen_loss_L1 0.34328604
# progress  epoch 10  step 49  image/sec 4.7  remaining 1m
# discrim_loss 0.5762922
# gen_loss_GAN 2.500255
# gen_loss_L1 0.350511
# recording summary
# progress  epoch 10  step 99  image/sec 4.7  remaining 1m
# discrim_loss 0.66374254
# gen_loss_GAN 2.3663507
# gen_loss_L1 0.3525755
# progress  epoch 10  step 150  image/sec 4.7  remaining 0m
# discrim_loss 0.6819014
# gen_loss_GAN 2.3704767
# gen_loss_L1 0.3438952
# recording summary
# progress  epoch 10  step 199  image/sec 4.7  remaining 0m
# discrim_loss 0.64761657
# gen_loss_GAN 2.380586
# gen_loss_L1 0.34546033
# progress  epoch 10  step 250  image/sec 4.7  remaining 0m
# discrim_loss 0.59908795
# gen_loss_GAN 2.3338542
# gen_loss_L1 0.34187534
# recording summary
# progress  epoch 10  step 300  image/sec 4.7  remaining 0m
# discrim_loss 0.6145828
# gen_loss_GAN 2.3154206
# gen_loss_L1 0.341433
# progress  epoch 10  step 349  image/sec 4.7  remaining 0m
# discrim_loss 0.6278439
# gen_loss_GAN 2.346258
# gen_loss_L1 0.3445241
# recording summary
# progress  epoch 10  step 399  image/sec 4.7  remaining 0m
# discrim_loss 0.6331909
# gen_loss_GAN 2.2852452
# gen_loss_L1 0.34334928
# saving model

# %%
#@title 学習モデルのテスト
# !python pix2pix.py \
  --mode test \
  --output_dir facades_test \
  --input_dir facades/val \
  --checkpoint facades_train
# Out:
# WARNING:tensorflow:From pix2pix.py:540: The name tf.set_random_seed is deprecated. Please use tf.compat.v1.set_random_seed instead.
#
# loaded lab_colorization = False
# loaded ndf = 64
# loaded ngf = 64
# loaded which_direction = BtoA
# aspect_ratio = 1.0
# batch_size = 1
# beta1 = 0.5
# checkpoint = facades_train
# display_freq = 0
# flip = False
# gan_weight = 1.0
# input_dir = facades/val
# l1_weight = 100.0
# lab_colorization = False
# lr = 0.0002
# max_epochs = None
# max_steps = None
# mode = test
# ndf = 64
# ngf = 64
# output_dir = facades_test
# output_filetype = png
# progress_freq = 50
# save_freq = 5000
# scale_size = 256
# seed = 983436401
# separable_conv = False
# summary_freq = 100
# trace_freq = 0
# which_direction = BtoA
# WARNING:tensorflow:From pix2pix.py:258: string_input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(string_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:277: input_producer (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensor_slices(input_tensor).shuffle(tf.shape(input_tensor, out_type=tf.int64)[0]).repeat(num_epochs)`. If `shuffle=False`, omit the `.shuffle(...)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:189: limit_epochs (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.from_tensors(tensor).repeat(num_epochs)`.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: QueueRunner.__init__ (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/training/input.py:198: add_queue_runner (from tensorflow.python.training.queue_runner_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# To construct input pipelines, use the `tf.data` module.
# WARNING:tensorflow:From pix2pix.py:259: WholeFileReader.__init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.map(tf.read_file)`.
# WARNING:tensorflow:From pix2pix.py:264: The name tf.assert_equal is deprecated. Please use tf.compat.v1.assert_equal instead.
#
# WARNING:tensorflow:From pix2pix.py:299: The name tf.image.resize_images is deprecated. Please use tf.image.resize instead.
#
# WARNING:tensorflow:From pix2pix.py:301: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From pix2pix.py:314: batch (from tensorflow.python.training.input) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.Dataset.batch(batch_size)` (or `padded_batch(...)` if `dynamic_pad=True`).
# examples count = 100
# WARNING:tensorflow:From pix2pix.py:428: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# WARNING:tensorflow:From pix2pix.py:105: conv2d (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2D` instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/layers/convolutional.py:424: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From pix2pix.py:132: batch_normalization (from tensorflow.python.layers.normalization) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.BatchNormalization instead.  In particular, `tf.control_dependencies(tf.GraphKeys.UPDATE_OPS)` should not be used (consult the `tf.keras.layers.batch_normalization` documentation).
# WARNING:tensorflow:From pix2pix.py:116: conv2d_transpose (from tensorflow.python.layers.convolutional) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.keras.layers.Conv2DTranspose` instead.
# WARNING:tensorflow:From pix2pix.py:379: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From pix2pix.py:448: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From pix2pix.py:458: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# WARNING:tensorflow:From pix2pix.py:459: The name tf.train.AdamOptimizer is deprecated. Please use tf.compat.v1.train.AdamOptimizer instead.
#
# WARNING:tensorflow:From pix2pix.py:473: The name tf.train.get_or_create_global_step is deprecated. Please use tf.compat.v1.train.get_or_create_global_step instead.
#
# WARNING:tensorflow:From pix2pix.py:474: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# WARNING:tensorflow:From pix2pix.py:681: The name tf.summary.image is deprecated. Please use tf.compat.v1.summary.image instead.
#
# WARNING:tensorflow:From pix2pix.py:695: The name tf.summary.scalar is deprecated. Please use tf.compat.v1.summary.scalar instead.
#
# WARNING:tensorflow:From pix2pix.py:700: The name tf.summary.histogram is deprecated. Please use tf.compat.v1.summary.histogram instead.
#
# WARNING:tensorflow:From pix2pix.py:708: The name tf.train.Saver is deprecated. Please use tf.compat.v1.train.Saver instead.
#
# WARNING:tensorflow:From pix2pix.py:711: Supervisor.__init__ (from tensorflow.python.training.supervisor) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please switch to tf.train.MonitoredTrainingSession
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/array_ops.py:1475: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# 2020-03-09 01:08:43.957368: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-03-09 01:08:43.976815: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:43.977614: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-03-09 01:08:43.977940: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 01:08:43.979746: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-09 01:08:43.981475: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-09 01:08:43.981822: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-09 01:08:43.983481: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-09 01:08:43.984425: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-09 01:08:43.988147: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 01:08:43.988261: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:43.989110: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:43.989853: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-09 01:08:43.995404: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2200000000 Hz
# 2020-03-09 01:08:43.995611: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12bcbc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-03-09 01:08:43.995645: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-03-09 01:08:44.041508: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.042422: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x12bcd80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-03-09 01:08:44.042456: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla K80, Compute Capability 3.7
# 2020-03-09 01:08:44.042731: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.043539: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1618] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# 2020-03-09 01:08:44.043618: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 01:08:44.043664: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# 2020-03-09 01:08:44.043714: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcufft.so.10
# 2020-03-09 01:08:44.043789: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcurand.so.10
# 2020-03-09 01:08:44.043833: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusolver.so.10
# 2020-03-09 01:08:44.043872: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcusparse.so.10
# 2020-03-09 01:08:44.043911: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 01:08:44.044004: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.044862: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.045615: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1746] Adding visible gpu devices: 0
# 2020-03-09 01:08:44.045681: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudart.so.10.1
# 2020-03-09 01:08:44.047045: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1159] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-03-09 01:08:44.047092: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1165]      0
# 2020-03-09 01:08:44.047109: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1178] 0:   N
# 2020-03-09 01:08:44.047293: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.048050: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:983] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-03-09 01:08:44.048826: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-03-09 01:08:44.048877: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1304] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10805 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# parameter_count = 57190084
# loading model from checkpoint
# 2020-03-09 01:08:50.343875: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcudnn.so.7
# 2020-03-09 01:08:51.119262: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcublas.so.10
# evaluated image 1
# evaluated image 2
# evaluated image 3
# evaluated image 4
# evaluated image 5
# evaluated image 6
# evaluated image 7
# evaluated image 8
# evaluated image 9
# evaluated image 10
# evaluated image 11
# evaluated image 12
# evaluated image 13
# evaluated image 14
# evaluated image 15
# evaluated image 16
# evaluated image 17
# evaluated image 18
# evaluated image 19
# evaluated image 20
# evaluated image 21
# evaluated image 22
# evaluated image 23
# evaluated image 24
# evaluated image 25
# evaluated image 26
# evaluated image 27
# evaluated image 28
# evaluated image 29
# evaluated image 30
# evaluated image 31
# evaluated image 32
# evaluated image 33
# evaluated image 34
# evaluated image 35
# evaluated image 36
# evaluated image 37
# evaluated image 38
# evaluated image 39
# evaluated image 40
# evaluated image 41
# evaluated image 42
# evaluated image 43
# evaluated image 44
# evaluated image 45
# evaluated image 46
# evaluated image 47
# evaluated image 48
# evaluated image 49
# evaluated image 50
# evaluated image 51
# evaluated image 52
# evaluated image 53
# evaluated image 54
# evaluated image 55
# evaluated image 56
# evaluated image 57
# evaluated image 58
# evaluated image 59
# evaluated image 60
# evaluated image 61
# evaluated image 62
# evaluated image 63
# evaluated image 64
# evaluated image 65
# evaluated image 66
# evaluated image 67
# evaluated image 68
# evaluated image 69
# evaluated image 70
# evaluated image 71
# evaluated image 72
# evaluated image 73
# evaluated image 74
# evaluated image 75
# evaluated image 76
# evaluated image 77
# evaluated image 78
# evaluated image 79
# evaluated image 80
# evaluated image 81
# evaluated image 82
# evaluated image 83
# evaluated image 84
# evaluated image 85
# evaluated image 86
# evaluated image 87
# evaluated image 88
# evaluated image 89
# evaluated image 90
# evaluated image 91
# evaluated image 92
# evaluated image 93
# evaluated image 94
# evaluated image 95
# evaluated image 96
# evaluated image 97
# evaluated image 98
# evaluated image 99
# evaluated image 100
# wrote index at facades_test/index.html
# rate 0.09213826894760131

# %%
#@title テストの結果を自分のDrive以下の"school_mission_12/"にコピー
# !pwd
# !ls
# !cp -r ./facades_test '/content/drive/My Drive/school_mission_12'
# !ls '/content/drive/My Drive/school_mission_12'
# Out:
# /content/pix2pix-tensorflow
# docker	facades       facades_train  pix2pix.py  server
# docs	facades_test  LICENSE.txt    README.md	 tools
# events.out.tfevents.1581415940.280e22789da2  graph.pbtxt  index.html
# facades_test				     images	  options.json
